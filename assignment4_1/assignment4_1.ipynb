# %%
import pandas as pd
import numpy as np
from IPython.display import display
weights = [203.615021712,121.021256815,102.797881821,96.8308228425,
           85.1337376818,82.7638081862,79.8350001426,77.6664196111,
           74.6070181251,73.1094103855,69.0965599529,68.1365878361,
           66.4803049535,64.5130880771,63.5694364795]

user = pd.read_csv("data/Users.csv")
item = pd.read_csv("data/Items.csv")
display(user.head())
display(item.head())
# Out:
#    User         1         2         3         4         5         6         7  \
# 0  4768 -0.014298  0.014642 -0.008921  0.014074 -0.017659  0.018015  0.005764
# 1   156 -0.013291 -0.016269 -0.009024 -0.000084 -0.003538  0.019479 -0.010982
# 2  5323 -0.008081 -0.008262 -0.005240  0.001877 -0.007379 -0.000531  0.012647
# 3   174 -0.015941 -0.024773 -0.001699  0.005521  0.023275 -0.007985 -0.003707
# 4  4529 -0.001024 -0.009292 -0.010646  0.015831 -0.013370 -0.012996 -0.001516
#
#           8         9        10        11        12        13        14  \
# 0 -0.010051  0.014683  0.007715  0.010227  0.043056  0.000872 -0.014774
# 1 -0.007748 -0.001340  0.014136 -0.001195 -0.005888  0.005631  0.014152
# 2  0.011586  0.004024  0.000081 -0.008868 -0.002357  0.013291  0.006782
# 3 -0.009816 -0.015222  0.021099  0.011536 -0.009982  0.004509 -0.020597
# 4 -0.005744  0.006796 -0.018666 -0.017129 -0.016093 -0.004893  0.016069
#
#          15
# 0 -0.004907
# 1  0.022560
# 2 -0.013740
# ...

# %%
display(item.sort_values(by = "1",ascending = False).head())
display(item.sort_values(by = "2",ascending = False).head())
# Out:
#     Movie ID                              Title         1         2         3  \
# 86      4327            Charlie's Angels (2000)  0.281990  0.080262  0.112268
# 37       414              Batman Forever (1995)  0.218089 -0.009324  0.050725
# 85      3049  Ace Ventura: Pet Detective (1994)  0.190879  0.067747  0.002918
# 90      8467               Dumb & Dumber (1994)  0.190638  0.110683 -0.010021
# 68       854                    The Mask (1994)  0.158601 -0.006160 -0.020265
#
#            4         5         6         7         8         9        10  \
# 86 -0.043805  0.022552 -0.093860 -0.066124  0.047216  0.044850  0.061068
# 37 -0.073225  0.083830 -0.010205 -0.116477 -0.034974 -0.199162 -0.090010
# 85 -0.033348  0.074343  0.285012  0.386962 -0.088550 -0.025470 -0.153609
# 90 -0.012114  0.138720  0.308335  0.394490 -0.145662 -0.015438 -0.157104
# 68  0.007000 -0.020494  0.228476  0.273633 -0.008621 -0.078120 -0.023222
#
#           11        12        13        14        15
# ...

# %%
user.drop(["User"],axis = 1).head()
# Out:
# (25, 16)

# %%
item.drop(["Movie ID","Title"],axis = 1).mul(weights, axis=1)
# Out:
#             1          2          3          4          5          6  \
# 0  -21.715813 -11.424585  20.554339   2.439722  -5.485769  22.864286
# 1   -4.882766  -3.262738  -3.913246  24.042696 -10.121929  -5.635559
# 2  -31.976067  -4.827393 -23.067861   6.047319   8.345353   6.476658
# 3   -9.054366  24.048763  -0.676076   0.848200   4.775400  -1.685928
# 4    7.382226 -16.025797   3.742896   0.727223  -0.907291  -5.410461
# 5   -9.204021  21.973770  21.146008 -16.596191  -0.441728  -9.518441
# 6   -9.924900  19.491496   1.456420   2.408091   4.006479  -3.347817
# 7   -8.784561  15.297309   7.698699  -4.021273  -0.916916  -0.669021
# 8  -20.601124  16.134800  -1.235878  -2.341361  -2.777358  -5.914203
# 9  -17.718627   0.232453   4.959564   4.178015 -11.646546  10.831931
# 10 -19.475582 -14.346760 -19.685980  -6.504487   1.189122   0.064120
# 11 -15.805700  -0.434601   1.113345   1.664468 -14.997847  15.224552
# 12 -10.209731  16.789223   4.190244  -3.516169   1.459945   1.604339
# ...

# %%
res = pd.DataFrame(np.dot(item.drop(["Movie ID","Title"],axis = 1).mul(weights, axis=1),
                    user.drop(["User"],axis = 1).T),columns = user["User"],index = item[["Movie ID"]])

# %%
res.sort_values(by = 4469,ascending = False)
# Out:
# User       4768      156       5323      174       4529      783       3878  \
# 278    0.937787  0.293419  0.478752  0.668020  0.069928  0.176566  0.558141
# 453    0.080442  0.514953  0.181640  0.995228  0.089402  0.142198 -0.119408
# 98     0.195472  0.658106  0.543291  0.770433  0.146374  0.176392  0.136076
# 238    0.634223 -0.049005  0.694714  0.060033  0.163397  0.360008  0.417018
# 13     0.766364  0.396485  0.261073  1.212876 -0.285316  0.170626  0.205784
# 424    0.593612  0.199863  0.271648  0.558233 -0.017807  0.152208  0.345319
# 197    0.287472  0.404124  0.360666  0.776647 -0.266832  0.106490  0.036922
# 155    0.248981  0.702483  0.759871  0.315802  0.817499  0.049691  0.844621
# 597   -1.822833  0.101975  0.451547 -0.563474  1.625952  0.052196 -0.126943
# 857    0.450075  0.251416  0.228516  0.303603  0.165301  0.174347  0.216030
# 1422   0.378917  0.046813  0.283415 -0.069623  0.011385  0.122712  0.506230
# ...
